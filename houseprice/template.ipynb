# %% [markdown]
# # 🏠 House Price Prediction Lab - Solution
#
# **Project Description**:
#
# The goal of this project is to predict house price based on real estate features extracted for houses in Bengaluru. The major sequence of steps in the coding process are listed below:
#
# 1.   Load and clean up the data.
# 2.   Analyze the features (*ordinal, categorical*, and *continuous*) for missingness, correct data type association, and distribution.
# 3.   Spit the data into train and test sets..
# 4.   Build an ML pipeline (*encoder -> imputer -> regression module*) for the train set by specifying seperate ecoding and imputing steps (if needed) for ordinal, categorical, and continuous features.
# 5.   Train the ML pipeline on the train set and apply it for prediction on the test set.
# 6.   Report performance metrics

# %%
import pandas as pd
import numpy as np
import os
import sys
import math
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.style.use('dark_background')
# %matplotlib inline

## Pipeline module
from sklearn.pipeline import Pipeline

## Scaling, encoding, and imputation libraries
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer

# Column trandformation library
from sklearn.compose import ColumnTransformer

## Train-test, cross-validation, and grid search modules
from sklearn.model_selection import train_test_split

## Cross-validation and grid search modules
from sklearn.model_selection import KFold, StratifiedKFold, GridSearchCV, cross_val_score

## Regression modules
from sklearn import linear_model

## Performance metrics modules
from sklearn.metrics import mean_squared_error, r2_score

## Model serialization module
import joblib

# %% [markdown]
# ---
#
# Mount Google Drive if running in Colab
#
# ---

# %%
if('google.colab' in sys.modules):
    from google.colab import drive
    drive.mount('/content/drive', force_remount = True)
    DIR = '/content/drive/MyDrive/Colab Notebooks/MAHE/MSIS Coursework/OddSem2025MAHE/House Price Project/'
    DATA_DIR = DIR + '/Data/'
    os.chdir(DIR)
else:
    DATA_DIR = 'data/'

# %% [markdown]
# ---
#
# Load bengaluru house price data
#
# ---

# %%
file = DATA_DIR+'houseprices.csv'

df= pd.read_csv(file, header = 0)

print('Bengaluru house price dataset')
print('-----------')
print('Initial number of samples = %d'%(df.shape[0]))
print('Initial number of features = %d\n'%(df.shape[1]))
df.head()
# Out:
# Bengaluru house price dataset
# -----------
# Initial number of samples = 225
# Initial number of features = 8
#      locality    area      rent  price_per_sqft      facing  BHK  bathrooms  \
# 0  BTM Layout   565.0   20060.0          6195.0  North-West    1          1
# 1  BTM Layout  1837.0   97434.0          9254.0        East    3          3
# 2  BTM Layout  1280.0   54448.0          7422.0        East    2          2
# 3  BTM Layout  2220.0  117000.0          9234.0       North    3          3
# 4  BTM Layout  1113.0   34388.0          5391.0        East    2          2
#
#         parking
# 0          Bike
# 1  Bike and Car
# 2           Car
# 3  Bike and Car
# 4  Bike and Car

# %% [markdown]
# ---
#
# Plot percentage of missing values (NaNs) for each feature
#
# ---

# %%
cutoff = 10 # we will remove features missing in more than cutoff% of the samples
fig = plt.figure(figsize=(4, 4))
percent_missing = (df.isna().sum() / df.shape[0]) * 100
percent_missing.plot(kind = 'bar', color = cm.rainbow(np.linspace(0, 1, 2))[(percent_missing <= cutoff).values.astype(int)])
plt.plot(np.arange(df.shape[1]), np.repeat(cutoff, df.shape[1]), 'g--')
fig.suptitle('Percentage Missing Values Across All Features', fontsize = 10)
plt.xlabel('Feature', fontsize = 8)
plt.ylabel('% Missing Values', fontsize = 8)
# Out:
# Text(0, 0.5, '% Missing Values')

# %% [markdown]
# ---
#
# Create lists of ordinal, categorical, and continuous features
#
# ---

# %%
## Create lists of ordinal, categorical, and continuous features
ordinal_features = []
# ordinal_features = ['BHK','bathrooms']
# categorical_features = ['locality','facing','parking']
categorical_features = ['locality']
continuous_features = (df.drop(ordinal_features, axis = 1)).drop(categorical_features, axis = 1).columns.tolist()

# Remove target variable from continuous features
continuous_features.remove('price_per_sqft')
print(continuous_features)
# Out:
# ['area', 'rent', 'facing', 'BHK', 'bathrooms', 'parking']

# %% [markdown]
# ---
#
# Treat "missingness" as another level in the categorical variables
#
# ---

# %%
# Replace NaN with 'Missing' in categorical columns
df[categorical_features] = df[categorical_features].fillna('Missing')

# %% [markdown]
# ---
#
# Assign 'category' datatype to ordinal and categorical columns
#
# ---

# %%
df.dtypes
# Out:
# locality           object
# area              float64
# rent              float64
# price_per_sqft    float64
# facing             object
# BHK                 int64
# bathrooms           int64
# parking            object
# dtype: object

# %%
## Assign 'category' datatype to ordinal and categorical columns
print(df.dtypes)
df[ordinal_features + categorical_features] = df[ordinal_features+categorical_features].astype('category')
print('----')
df.dtypes
# Out:
# locality           object
# area              float64
# rent              float64
# price_per_sqft    float64
# facing             object
# BHK                 int64
# bathrooms           int64
# parking            object
# dtype: object
# ----
# locality          category
# area               float64
# rent               float64
# price_per_sqft     float64
# facing              object
# BHK                  int64
# bathrooms            int64
# parking             object
# dtype: object

# %% [markdown]
# ---
#
# Print unique values in each ordinal and categorical features
#
# ---

# %%
## Print unique values in each ordinal and categorical features
print(df[ordinal_features + categorical_features].nunique())
print('\nUnique values in ordinal and categorical features')
print('---------------------------------------------------')
unique_values = {col:list(df[col].unique()) for col in ordinal_features + categorical_features}
for key, value in unique_values.items():
  print(key,value)
# Out:
# locality    9
# dtype: int64
#
# Unique values in ordinal and categorical features
# ---------------------------------------------------
# locality ['BTM Layout', 'Attibele', 'K R Puram ', 'Marathahalli', 'Indiranagar', 'Electronic City', 'Yalahanka', 'Malleshwaram', 'Jayanagar']

# %% [markdown]
# ---
#
# Build pipeline for ordinal, categorical, and continuous features
#
# ---

# %%
from sklearn.preprocessing import FunctionTransformer
import numpy as np

# %%
## Build pipeline for ordinal, categorical, and continuous features

# Pipeline object for ordinal features
ordinal_transformer = Pipeline(steps = [('ordinalenc', OrdinalEncoder())])
ordinal_transformer = Pipeline(steps = [('ordinalenc', OrdinalEncoder())])

# Pipeline object for categorical (features
categorical_transformer = Pipeline(steps = [('onehotenc', OneHotEncoder(handle_unknown = 'ignore'))])
# Use the following if missing values are to be imputed
# categorical_transformer = Pipeline(steps = [('imputer', SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')), ('onehotenc', OneHotEncoder(handle_unknown = 'ignore'))])

# Pipeline object for continuous features
# continuous_transformer = Pipeline(steps = [('scaler', StandardScaler())])

def _log_transform_(x):
    return np.log(x)

log_transform = FunctionTransformer(_log_transform_,validate=False)

# Create a preprocessor object for all features
preprocessor = ColumnTransformer(transformers = [('logtransform',log_transform,continuous_features),
                                                 ('categorical', categorical_transformer, categorical_features),
                                                 ('ordinal', ordinal_transformer, ordinal_features)
                                                ],
                                 remainder = 'passthrough'
                                 )

# Define a regressor object
regressor = linear_model.LinearRegression()

# Define the entire classification model pipeline
model_pipeline = Pipeline(steps=[('preprocessor',preprocessor),('regressor',regressor)])

# %%
# ## Build pipeline for ordinal, categorical, and continuous features

# # Pipeline object for ordinal features
# ordinal_transformer = Pipeline(steps = [('ordinalenc', OrdinalEncoder())])

# # Pipeline object for categorical (features
# categorical_transformer = Pipeline(steps = [('onehotenc', OneHotEncoder(handle_unknown = 'ignore'))])
# # Use the following if missing values are to be imputed
# # categorical_transformer = Pipeline(steps = [('imputer', SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')), ('onehotenc', OneHotEncoder(handle_unknown = 'ignore'))])

# # Pipeline object for continuous features
# continuous_transformer = Pipeline(steps = [('scaler', StandardScaler())])

# # Create a preprocessor object for all features
# preprocessor = ColumnTransformer(transformers = [('continuous', continuous_transformer, continuous_features),
#                                                  ('categorical', categorical_transformer, categorical_features),
#                                                  ('ordinal', ordinal_transformer, ordinal_features)
#                                                 ],
#                                  remainder = 'passthrough'
#                                  )

# # Define a regressor object
# regressor = linear_model.LinearRegression()

# # Define the entire classification model pipeline
# model_pipeline = Pipeline(steps=[('preprocessor',preprocessor),('regressor',regressor)])

# %% [markdown]
# ---
#
# Train-test split of the dataset
#
# ---

# %%
df
# Out:
#        locality    area      rent  price_per_sqft      facing  BHK  bathrooms  \
# 0    BTM Layout   565.0   20060.0          6195.0  North-West    1          1
# 1    BTM Layout  1837.0   97434.0          9254.0        East    3          3
# 2    BTM Layout  1280.0   54448.0          7422.0        East    2          2
# 3    BTM Layout  2220.0  117000.0          9234.0       North    3          3
# 4    BTM Layout  1113.0   34388.0          5391.0        East    2          2
# ..          ...     ...       ...             ...         ...  ...        ...
# 220   Jayanagar  1060.0   45851.0          7547.0         NaN    2          2
# 221   Jayanagar  2000.0   85971.0          7500.0        East    3          3
# 222   Jayanagar  1340.0   77947.0         10149.0        East    3          2
# 223   Jayanagar  5100.0  430000.0         14706.0        East    4          5
# 224   Jayanagar  1340.0   74508.0          9701.0        East    3          2
#
#           parking
# 0            Bike
# 1    Bike and Car
# 2             Car
# 3    Bike and Car
# 4    Bike and Car
# ..            ...
# 220  Bike and Car
# 221  Bike and Car
# 222  Bike and Car
# 223  Bike and Car
# 224  Bike and Car
#
# [225 rows x 8 columns]

# %%
## Train and test split of the data
X = df.drop('price_per_sqft',axis=1)
y = df['price_per_sqft']
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.10,
                                                    random_state = 1)
print(f'# training samples = {X_train.shape[0]}, # test samples = {X_test.shape[0]}')
# Out:
# # training samples = 202, # test samples = 23

# %% [markdown]
# ---
#
# Fit the pipeline on the train data and test on the test data
#
# ---

# %%
## Fit the model pipeline on the train data and test on the test data
model_pipeline.fit(X_train, y_train)
y_pred = model_pipeline.predict(X_test)
print(f'Root Mean Squared Error = {np.sqrt(mean_squared_error(y_test,y_pred))}')
print(f'r2_score = {r2_score(y_test, y_pred)}')
X_train
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'str' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[123], line 2
#       1 ## Fit the model pipeline on the train data and test on the test data
# ----> 2 model_pipeline.fit(X_train, y_train)
#       3 y_pred = model_pipeline.predict(X_test)
#       4 print(f'Root Mean Squared Error = {np.sqrt(mean_squared_error(y_test,y_pred))}')
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\pipeline.py:655, in Pipeline.fit(self, X, y, **params)
#     648     raise ValueError(
#     649         "The `transform_input` parameter can only be set if metadata "
#     650         "routing is enabled. You can enable metadata routing using "
#     651         "`sklearn.set_config(enable_metadata_routing=True)`."
#     652     )
#     654 routed_params = self._check_method_params(method="fit", props=params)
# --> 655 Xt = self._fit(X, y, routed_params, raw_params=params)
#     656 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     657     if self._final_estimator != "passthrough":
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\pipeline.py:589, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     582 # Fit or load from cache the current transformer
#     583 step_params = self._get_metadata_for_step(
#     584     step_idx=step_idx,
#     585     step_params=routed_params[name],
#     586     all_params=raw_params,
#     587 )
# --> 589 X, fitted_transformer = fit_transform_one_cached(
#     590     cloned_transformer,
#     591     X,
#     592     y,
#     593     weight=None,
#     594     message_clsname="Pipeline",
#     595     message=self._log_message(step_idx),
#     596     params=step_params,
#     597 )
#     598 # Replace the transformer of the step with the fitted
#     599 # transformer. This is necessary when loading the transformer
#     600 # from the cache.
#     601 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\joblib\memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\pipeline.py:1540, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1538 with _print_elapsed_time(message_clsname, message):
#    1539     if hasattr(transformer, "fit_transform"):
# -> 1540         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1541     else:
#    1542         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1543             X, **params.get("transform", {})
#    1544         )
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\compose\_column_transformer.py:996, in ColumnTransformer.fit_transform(self, X, y, **params)
#     993 else:
#     994     routed_params = self._get_empty_routing()
# --> 996 result = self._call_func_on_transformers(
#     997     X,
#     998     y,
#     999     _fit_transform_one,
#    1000     column_as_labels=False,
#    1001     routed_params=routed_params,
#    1002 )
#    1004 if not result:
#    1005     self._update_fitted_transformers([])
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\compose\_column_transformer.py:897, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     885             extra_args = {}
#     886         jobs.append(
#     887             delayed(func)(
#     888                 transformer=clone(trans) if not fitted else trans,
#    (...)    894             )
#     895         )
# --> 897     return Parallel(n_jobs=self.n_jobs)(jobs)
#     899 except ValueError as e:
#     900     if "Expected 2D array, got 1D array instead" in str(e):
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\utils\parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\utils\parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\pipeline.py:1540, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1538 with _print_elapsed_time(message_clsname, message):
#    1539     if hasattr(transformer, "fit_transform"):
# -> 1540         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1541     else:
#    1542         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1543             X, **params.get("transform", {})
#    1544         )
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\base.py:897, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     894     return self.fit(X, **fit_params).transform(X)
#     895 else:
#     896     # fit method of arity 2 (supervised transformation)
# --> 897     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\preprocessing\_function_transformer.py:260, in FunctionTransformer.transform(self, X)
#     246 """Transform X using the forward function.
#     247
#     248 Parameters
#    (...)    257     Transformed input.
#     258 """
#     259 X = self._check_input(X, reset=False)
# --> 260 out = self._transform(X, func=self.func, kw_args=self.kw_args)
#     261 output_config = _get_output_config("transform", self)["dense"]
#     263 if hasattr(out, "columns") and self.feature_names_out is not None:
#     264     # check the consistency between the column provided by `transform` and
#     265     # the column names provided by `get_feature_names_out`.
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\sklearn\preprocessing\_function_transformer.py:387, in FunctionTransformer._transform(self, X, func, kw_args)
#     384 if func is None:
#     385     func = _identity
# --> 387 return func(X, **(kw_args if kw_args else {}))
#
# Cell In[119], line 15, in _log_transform_(x)
#      14 def _log_transform_(x):
# ---> 15     return np.log(x)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\pandas\core\generic.py:2190, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2186 @final
#    2187 def __array_ufunc__(
#    2188     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2189 ):
# -> 2190     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\pandas\core\arraylike.py:407, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     402 if method == "__call__" and not kwargs:
#     403     # for np.<ufunc>(..) calls
#     404     # kwargs cannot necessarily be handled block-by-block, so only
#     405     # take this path if there are no kwargs
#     406     mgr = inputs[0]._mgr
# --> 407     result = mgr.apply(getattr(ufunc, method))
#     408 else:
#     409     # otherwise specific ufunc methods (eg np.<ufunc>.accumulate(..))
#     410     # Those can have an axis keyword and thus can't be called block-by-block
#     411     result = default_array_ufunc(inputs[0], ufunc, method, *inputs, **kwargs)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# TypeError: loop of ufunc does not support argument 0 of type str which has no callable log method

# %% [markdown]
# ---
#
# Save model
#
# ---

# %%
joblib.dump(model_pipeline, '../model.pkl')
# Out:
# ['../model.pkl']
