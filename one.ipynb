# %%
from lamini import Lamini

non_finetuned = Lamini("meta-llama/Llama-2-7b-hf")
non_finetuned.generate("Tell me how to train my dog to sit")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from lamini import Lamini
#       3 non_finetuned = Lamini("meta-llama/Llama-2-7b-hf")
#       4 non_finetuned.generate("Tell me how to train my dog to sit")
#
# ModuleNotFoundError: No module named 'lamini'

# %%
import jsonlines
import iteratools
import pandas as pd 

import datasets
from datasets import load_dataset

trained_dataset = load_dataset('EleutherAI/pile',split="train",streaming=True)

# %%
Instructor (
    ins_id:     unique identification number of the instructors,    
    lastname:   last name of the instructors,
    firstname:  first name of the instructors,
    city:       name of the cities where instructors are located,
    country:    two-letter country code of the countries where instructors are located
)
