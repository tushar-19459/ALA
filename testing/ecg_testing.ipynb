# %%
import torch
import numpy as np
import pandas as pd

# %%
data = torch.tensor([30,40,60])
a = .diag(2,0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 data = torch.tensor([30,40,60])
# ----> 2 a = np.diag(2,0)
#
# File c:\Users\Dell\miniconda3\envs\ALA\Lib\site-packages\numpy\lib\_twodim_base_impl.py:328, in diag(v, k)
#     326     return diagonal(v, k)
#     327 else:
# --> 328     raise ValueError("Input must be 1- or 2-d.")
#
# ValueError: Input must be 1- or 2-d.
